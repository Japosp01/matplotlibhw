# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_data=pd.read_csv(r"C:\Users\The Doctor\Anaconda3\envs\PythonData\mouse_drug_data.csv")
mouse_data
# Out:
#     Mouse ID      Drug
# 0       f234  Stelasyn
# 1       x402  Stelasyn
# 2       a492  Stelasyn
# 3       w540  Stelasyn
# 4       v764  Stelasyn
# 5       o848  Stelasyn
# 6       z314  Stelasyn
# 7       g989  Stelasyn
# 8       m269  Stelasyn
# 9       a963  Stelasyn
# 10      t451  Stelasyn
# 11      p981  Stelasyn
# 12      k510  Stelasyn
# 13      h333  Stelasyn
# 14      c402  Stelasyn
# 15      j984  Stelasyn
# 16      w697  Stelasyn
# 17      s619  Stelasyn
# 18      g867  Stelasyn
# 19      k862  Stelasyn
# 20      i901  Stelasyn
# 21      b879  Stelasyn
# 22      p387  Stelasyn
# 23      a366  Stelasyn
# 24      s565  Stelasyn
# 25      j755  Naftisol
# 26      e213  Naftisol
# 27      e584  Naftisol
# 28      e291  Naftisol
# 29      z795  Naftisol
# ..       ...       ...
# 220     a444  Ramicane
# 221     a411  Ramicane
# 222     j913  Ramicane
# 223     q610  Ramicane
# 224     c458  Ramicane
# 225     a897   Placebo
# 226     c757   Placebo
# 227     i477   Placebo
# ...

# %%
clinical_data=pd.read_csv(r"C:\Users\The Doctor\Anaconda3\envs\PythonData\clinicaltrial_data.csv")
clinical_data
# Out:
#      Mouse ID  Timepoint  Tumor_Volume  Metastatic Sites
# 0        b128          0     45.000000                 0
# 1        f932          0     45.000000                 0
# 2        g107          0     45.000000                 0
# 3        a457          0     45.000000                 0
# 4        c819          0     45.000000                 0
# 5        h246          0     45.000000                 0
# 6        p189          0     45.000000                 0
# 7        n923          0     45.000000                 0
# 8        q119          0     45.000000                 0
# 9        f993          0     45.000000                 0
# 10       z234          0     45.000000                 0
# 11       b559          0     45.000000                 0
# 12       y260          0     45.000000                 0
# 13       x930          0     45.000000                 0
# 14       o725          0     45.000000                 0
# ...

# %%
# Merge two dataframes 
merge_mouse = pd.merge(mouse_data, clinical_data, on="Mouse ID")
merge_mouse
# Out:
#      Mouse ID      Drug  Timepoint  Tumor_Volume  Metastatic Sites
# 0        f234  Stelasyn          0     45.000000                 0
# 1        f234  Stelasyn          5     47.313491                 0
# 2        f234  Stelasyn         10     47.904324                 0
# 3        f234  Stelasyn         15     48.735197                 1
# 4        f234  Stelasyn         20     51.112713                 2
# 5        f234  Stelasyn         25     52.178602                 2
# 6        f234  Stelasyn         30     56.873817                 2
# 7        f234  Stelasyn         35     57.748758                 2
# 8        x402  Stelasyn          0     45.000000                 0
# 9        x402  Stelasyn          5     46.327570                 1
# 10       x402  Stelasyn         10     46.886962                 1
# 11       x402  Stelasyn         15     49.119948                 1
# 12       x402  Stelasyn         20     50.414750                 2
# ...

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
drug_avg_tumor_vol = merge_mouse[["Drug", "Timepoint","Tumor_Volume"]]
grouped_drug_avg_tumor_vol = drug_avg_tumor_vol.groupby(['Drug', 'Timepoint'])

# %%
# Convert to DataFrame
tumor_vol = pd.DataFrame(grouped_drug_avg_tumor_vol["Tumor_Volume"].agg(np.mean))
tumor_vol.head()
# Out:
#                      Tumor_Volume
# Drug      Timepoint
# Capomulin 0             45.000000
#           5             44.266086
#           10            43.084291
#           15            42.064317
#           20            40.716325

# %%
# Preview DataFrame
tumor_vol_indexed = tumor_vol.reset_index()
tumor_vol_indexed
# Out:
#          Drug  Timepoint  Tumor_Volume
# 0   Capomulin          0     45.000000
# 1   Capomulin          5     44.266086
# 2   Capomulin         10     43.084291
# 3   Capomulin         15     42.064317
# 4   Capomulin         20     40.716325
# 5   Capomulin         25     39.939528
# 6   Capomulin         30     38.769339
# 7   Capomulin         35     37.816839
# 8   Capomulin         40     36.958001
# 9   Capomulin         45     36.236114
# 10   Ceftamin          0     45.000000
# 11   Ceftamin          5     46.503051
# 12   Ceftamin         10     48.285125
# 13   Ceftamin         15     50.094055
# 14   Ceftamin         20     52.157049
# 15   Ceftamin         25     54.287674
# 16   Ceftamin         30     56.769517
# 17   Ceftamin         35     58.827548
# 18   Ceftamin         40     61.467895
# 19   Ceftamin         45     64.132421
# 20  Infubinol          0     45.000000
# 21  Infubinol          5     47.062001
# 22  Infubinol         10     49.403909
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-130-b35cd6ef4c41> in <module>
#       3
#       4 # Convert to DataFrame
# ----> 5 tumor_vol_pd = pd.DataFrame(tumor_vol[["Tumor_Volume (mm3)"]])
#       6
#       7 # Preview DataFrame
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# ...

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
tumor_vol2 = merge_mouse.groupby(['Drug', 'Timepoint']).sem()
tumor_vol2
# Out:
#                      Metastatic Sites  Mouse ID  Tumor_Volume
# Drug      Timepoint
# Capomulin 0                  0.000000       NaN      0.000000
#           5                  0.074833       NaN      0.448593
#           10                 0.125433       NaN      0.702684
#           15                 0.132048       NaN      0.838617
#           20                 0.161621       NaN      0.909731
#           25                 0.181818       NaN      0.881642
#           30                 0.172944       NaN      0.934460
#           35                 0.169496       NaN      1.052241
#           40                 0.175610       NaN      1.223608
#           45                 0.202591       NaN      1.223977
# Ceftamin  0                  0.000000       NaN      0.000000
#           5                  0.108588       NaN      0.164505
#           10                 0.152177       NaN      0.236144
#           15                 0.180625       NaN      0.332053
# ...

# %%
# Convert to DataFrame
tumor_vol2_pd = pd.DataFrame(tumor_vol2[["Tumor_Volume"]])

# Preview DataFrame
tumorvol_sem = tumor_vol2_pd.reset_index()
tumorvol_sem.head()
# Out:
#         Drug  Timepoint  Tumor_Volume
# 0  Capomulin          0      0.000000
# 1  Capomulin          5      0.448593
# 2  Capomulin         10      0.702684
# 3  Capomulin         15      0.838617
# 4  Capomulin         20      0.909731

# %%
# Minor Data Munging to squish stuff around
#I don't know if munging is a real word but I'll google it later
drug_vol_stuff = tumor_vol_indexed.pivot(index="Timepoint", columns="Drug", values="Tumor_Volume")

# Preview that Reformatting worked
drug_vol_stuff.head()
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
#squish se
tumor_vol_se = tumorvol_sem.pivot(index="Timepoint", columns="Drug", values="Tumor_Volume")

# Preview that Reformatting worked
tumor_vol_se.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.231708  0.482955  0.239862   0.188950
# 10         0.376195  0.720225  0.433678   0.263949
# 15         0.466109  0.770432  0.493261   0.370544
# 20         0.555181  0.786199  0.621889   0.533182

# %%
# Generate the Plot (with Error Bars)
#this is way long and I hate typing
#luckily I hate the NFC North so vikingd packers is boring
#god i miss the southeast, richmond, etc
x_axis = np.arange(0, len(drug_vol_stuff), 1)
cap_vol = plt.errorbar(x_axis, drug_vol_stuff["Capomulin"], yerr=tumor_vol_se["Capomulin"], linestyle = "-.",marker="o", color="red", label="Capomulin")
ceft_vol = plt.errorbar(x_axis, drug_vol_stuff["Ceftamin"], yerr=tumor_vol_se["Ceftamin"], linestyle = "-.",marker="o", color="orange", label="Ceftamin")
inf_vol = plt.errorbar(x_axis, drug_vol_stuff["Infubinol"], yerr=tumor_vol_se["Infubinol"], linestyle = "--",marker="o", color="blue", label="Infubinol")

Keta_vol = plt.errorbar(x_axis, drug_vol_stuff["Ketapril"], yerr=tumor_vol_se["Ketapril"], linestyle = "-.",marker="o", color="yellow", label="Ketapril")
Naft_vol = plt.errorbar(x_axis, drug_vol_stuff["Naftisol"], yerr=tumor_vol_se["Naftisol"], linestyle = "-.",marker="o", color="red", label="Naftisol")
pla_vol = plt.errorbar(x_axis, drug_vol_stuff["Placebo"], yerr=tumor_vol_se["Placebo"], linestyle = "-.", marker="o", color="black", label="Placebo")
prop_vol = plt.errorbar(x_axis, drug_vol_stuff["Propriva"], yerr=tumor_vol_se["Propriva"], linestyle = "-.", marker="o", color="cyan", label="Propriva")
Ram_vol = plt.errorbar(x_axis, drug_vol_stuff["Ramicane"], yerr=tumor_vol_se["Ramicane"], linestyle = "-.", marker="o", color="magenta", label="Ramicane")
Stel_vol = plt.errorbar(x_axis, drug_vol_stuff["Stelasyn"], yerr=tumor_vol_se["Stelasyn"], linestyle = "-.", marker="o", color="black", label="Stelasyn")
Zdrug_vol = plt.errorbar(x_axis, drug_vol_stuff["Zoniferol"], yerr=tumor_vol_se["Zoniferol"], linestyle = "-.", marker="o", color="black", label="Zoniferol")


plt.legend(handles=[cap_vol, ceft_vol,inf_vol,Keta_vol,Naft_vol,pla_vol,prop_vol,Ram_vol,Stel_vol,Zdrug_vol], loc="upper left")
plt.title("Tumor Response to Treatment")
plt.ylabel("Tumor Volume (mm3)")
plt.xlabel("Time")
plt.grid()
plt.yticks(np.arange(0,200,20),("0", "35", "40", "45", "50","55","60","65","70"))
plt.xticks(np.arange(0,10,2),("0", "10", "20", "30", "40"))
plt.show()
#maybe try to spread this out more once I get all the other graphs in place
#think worked but hard to see se

# %%
#metastatic crap
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame

metastatic_mean = pd.DataFrame(merge_mouse.groupby(["Drug", "Timepoint"]).mean()["Metastatic Sites"])
# Preview DataFrame
metastatic_mean.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
#get standard error
metastatic_sem = pd.DataFrame(merge_mouse.groupby(["Drug", "Timepoint"]).sem()["Metastatic Sites"])

# Preview DataFrame
metastatic_sem.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
#flippity on the dataframes
metastatic_vol = metastatic_mean.reset_index().pivot(index="Timepoint", columns="Drug", values="Metastatic Sites")
metastatic_sem_flippity = metastatic_sem.reset_index().pivot(index="Timepoint", columns="Drug", values="Metastatic Sites")

# %%
#did the flippity work
metastatic_vol.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.320000  0.120000  0.240000   0.166667
# 10         0.565217  0.250000  0.478261   0.500000
# 15         0.764706  0.333333  0.782609   0.809524
# 20         1.000000  0.347826  0.952381   1.294118

# %%
# Generate the Plot (with Error Bars)
x_axis = np.arange(0, len(metastatic_vol), 1)
cap_ms = plt.errorbar(x_axis, metastatic_vol["Capomulin"], yerr=metastatic_sem_flippity["Capomulin"], linestyle = "-",marker="o", color="red", label="Capomulin")

ceft_ms = plt.errorbar(x_axis, metastatic_vol["Ceftamin"], yerr=metastatic_sem_flippity["Ceftamin"], linestyle = "-.",marker="o", color="orange", label="Ceftamin")
inf_ms = plt.errorbar(x_axis, metastatic_vol["Infubinol"], yerr=metastatic_sem_flippity["Infubinol"], linestyle = "-",marker="o", color="blue", label="Infubinol")



Keta_ms = plt.errorbar(x_axis, metastatic_vol["Ketapril"], yerr=metastatic_sem_flippity["Ketapril"], linestyle = "-", marker="o", color="green", label="Ketapril")


Naft_ms = plt.errorbar(x_axis, metastatic_vol["Naftisol"], yerr=metastatic_sem_flippity["Naftisol"], linestyle = "-.",marker="o", color="purple", label="Naftisol")

pla_ms = plt.errorbar(x_axis, metastatic_vol["Placebo"], yerr=metastatic_sem_flippity["Placebo"], linestyle = "-", marker="o", color="yellow", label="Placebo")

prop_ms = plt.errorbar(x_axis, metastatic_vol["Propriva"], yerr=metastatic_sem_flippity["Propriva"], linestyle = "-.", marker="o", color="cyan", label="Propriva")

Ram_ms = plt.errorbar(x_axis, metastatic_vol["Ramicane"], yerr=metastatic_sem_flippity["Ramicane"], linestyle = "-.", marker="o", color="magenta", label="Ramicane")

Stel_ms = plt.errorbar(x_axis, metastatic_vol["Stelasyn"], yerr=metastatic_sem_flippity["Stelasyn"], linestyle = "-.", marker="o", color="black", label="Stelasyn")

Zdrug_ms = plt.errorbar(x_axis, metastatic_vol["Zoniferol"], yerr=metastatic_sem_flippity["Zoniferol"], linestyle = "-.", marker="o", color="brown", label="Zoniferol")



plt.legend(handles=[cap_ms, ceft_ms,inf_ms,Keta_ms,Naft_ms,pla_ms,prop_ms,Ram_ms,Stel_ms,Zdrug_ms], loc="upper left")



plt.title("Metastatic Spread During Treatment")
plt.ylabel("Metastatic Sites")
plt.xlabel("Treatment Duration (Days)")
plt.grid()
plt.xticks(np.arange(0,10,2),("0", "10", "20", "30", "40"))
plt.show()

# %%
#Creating a scatter plot that shows the number of mice still alive through the course of treatment (Survival Rate)
#count mice alive at timepoints relative to t=0? so at each point

# %%
survival_grp = merge_mouse.groupby(["Drug", "Timepoint"])
survival_grp.head()
# Out:
#      Mouse ID      Drug  Timepoint  Tumor_Volume  Metastatic Sites
# 0        f234  Stelasyn          0     45.000000                 0
# 1        f234  Stelasyn          5     47.313491                 0
# 2        f234  Stelasyn         10     47.904324                 0
# 3        f234  Stelasyn         15     48.735197                 1
# 4        f234  Stelasyn         20     51.112713                 2
# 5        f234  Stelasyn         25     52.178602                 2
# 6        f234  Stelasyn         30     56.873817                 2
# 7        f234  Stelasyn         35     57.748758                 2
# 8        x402  Stelasyn          0     45.000000                 0
# 9        x402  Stelasyn          5     46.327570                 1
# 10       x402  Stelasyn         10     46.886962                 1
# 11       x402  Stelasyn         15     49.119948                 1
# 12       x402  Stelasyn         20     50.414750                 2
# ...

# %%
# Convert to DataFrame
survival_df = pd.DataFrame(survival_grp["Mouse ID"].count())
survival_alive = survival_df.rename(columns={"Mouse ID":"Mice Alive"})
survival_index = survival_alive.reset_index()

# Preview DataFrame
survival_index.head()
# Out:
#         Drug  Timepoint  Mice Alive
# 0  Capomulin          0          25
# 1  Capomulin          5          25
# 2  Capomulin         10          25
# 3  Capomulin         15          24
# 4  Capomulin         20          23

# %%
#flippity on the dataframes
survival_flippity = survival_index.pivot(index="Timepoint", columns="Drug", values="Mice Alive")
survival_flippity.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# Generate the Plot (Error Bars doesn't seem to fit since this is counting mice by drug by timepoint rather than averages)
x_axis = np.arange(0, len(drug_vol_stuff), 1)
cap_ms = plt.errorbar(x_axis, metastatic_vol["Capomulin"], yerr=metastatic_sem_flippity["Capomulin"], linestyle = "-",marker="o", color="red", label="Capomulin")

ceft_ms = plt.errorbar(x_axis, metastatic_vol["Ceftamin"], yerr=metastatic_sem_flippity["Ceftamin"], linestyle = "-.",marker="o", color="orange", label="Ceftamin")
inf_ms = plt.errorbar(x_axis, metastatic_vol["Infubinol"], yerr=metastatic_sem_flippity["Infubinol"], linestyle = "-",marker="x", color="blue", label="Infubinol")



Keta_ms = plt.errorbar(x_axis, metastatic_vol["Ketapril"], yerr=metastatic_sem_flippity["Ketapril"], linestyle = "-", marker="s", color="green", label="Ketapril")


Naft_ms = plt.errorbar(x_axis, metastatic_vol["Naftisol"], yerr=metastatic_sem_flippity["Naftisol"], linestyle = "-.",marker="o", color="red", label="Naftisol")

pla_ms = plt.errorbar(x_axis, metastatic_vol["Placebo"], yerr=metastatic_sem_flippity["Placebo"], linestyle = "-", marker="d", color="black", label="Placebo")

prop_ms = plt.errorbar(x_axis, metastatic_vol["Propriva"], yerr=metastatic_sem_flippity["Propriva"], linestyle = "-.", marker="d", color="cyan", label="Propriva")

Ram_ms = plt.errorbar(x_axis, metastatic_vol["Ramicane"], yerr=metastatic_sem_flippity["Ramicane"], linestyle = "-.", marker="d", color="magenta", label="Ramicane")

Stel_ms = plt.errorbar(x_axis, metastatic_vol["Stelasyn"], yerr=metastatic_sem_flippity["Stelasyn"], linestyle = "-.", marker="d", color="black", label="Stelasyn")

Zdrug_ms = plt.errorbar(x_axis, metastatic_vol["Zoniferol"], yerr=metastatic_sem_flippity["Zoniferol"], linestyle = "-.", marker="d", color="black", label="Zoniferol")



plt.legend(handles=[cap_ms, ceft_ms,inf_ms,Keta_ms,Naft_ms,pla_ms,prop_ms,Ram_ms,Stel_ms,Zdrug_ms], loc="upper left")



plt.title("Metastatic Spread During Treatment")
plt.ylabel("Metastatic Sites")
plt.xlabel("Treatment Duration (Days)")
plt.grid()
plt.xticks(np.arange(0,10,2),("0", "10", "20", "30", "40"))
plt.show()

# %%
x_axis = np.arange(0, len(drug_vol_stuff), 1)
cap_surv = plt.errorbar(x_axis, survival_flippity["Capomulin"]], linestyle = "-",marker="o", color="red", label="Capomulin")

ceft_surv = plt.errorbar(x_axis, survival_flippity["Ceftamin"], yerr=metastatic_sem_flippity["Ceftamin"], linestyle = "-.",marker="o", color="orange", label="Ceftamin")
inf_surv = plt.errorbar(x_axis, survival_flippity["Infubinol"], yerr=metastatic_sem_flippity["Infubinol"], linestyle = "-",marker="x", color="blue", label="Infubinol")



Keta_surv = plt.errorbar(x_axis, survival_flippity["Ketapril"], yerr=metastatic_sem_flippity["Ketapril"], linestyle = "-", marker="s", color="green", label="Ketapril")


Naft_surv = plt.errorbar(x_axis, survival_flippity["Naftisol"], yerr=metastatic_sem_flippity["Naftisol"], linestyle = "-.",marker="o", color="red", label="Naftisol")

pla_surv = plt.errorbar(x_axis, survival_flippity["Placebo"], yerr=metastatic_sem_flippity["Placebo"], linestyle = "-", marker="d", color="black", label="Placebo")

prop_surv = plt.errorbar(x_axis, survival_flippity["Propriva"], yerr=metastatic_sem_flippity["Propriva"], linestyle = "-.", marker="d", color="cyan", label="Propriva")

Ram_surv = plt.errorbar(x_axis, survival_flippity["Ramicane"], yerr=metastatic_sem_flippity["Ramicane"], linestyle = "-.", marker="d", color="magenta", label="Ramicane")

Stel_surv = plt.errorbar(x_axis, survival_flippity["Stelasyn"], yerr=metastatic_sem_flippity["Stelasyn"], linestyle = "-.", marker="d", color="black", label="Stelasyn")

Zdrug_surv = plt.errorbar(x_axis, survival_flippity["Zoniferol"], yerr=metastatic_sem_flippity["Zoniferol"], linestyle = "-.", marker="d", color="black", label="Zoniferol")

# %%
y_axis = [survival_flippity["Capomulin"]*4, survival_flippity["Ceftamin"]*4, survival_flippity["Infubinol"]*4, survival_flippity["Ketapril"]*4, survival_flippity["Naftisol"]*4, survival_flippity["Placebo"]*4,
          survival_flippity["Propriva"]*4, survival_flippity["Ramicane"]*4, survival_flippity["Stelasyn"],survival_flippity["Zoniferol"]*4]
          
labels = ["Capomulin", "Ceftamin", "Infubinol", "Ketapril", "Naftisol", "Placebo","Propriva", "Ramicane", "Stelasyn", "Zoniferol"]
colors = ["red", "blue", "green", "black", "orange", "cyan", "magenta", "yellow", "purple", "brown"]
linestyles = ["-", "-", "-", "-", "-", "-", "-", "-", "-", "-" ]
markers = ["o", "o","o","o","o","o","o","o","o","o"]
for x in range(len(y_axis)):
    plt.plot(x_axis, y_axis[x], color=colors[x], linestyle = linestyles[x], marker=markers[x], label=labels[x])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Put a legend to the right of the current axis
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title("Survival During Treatment")
plt.ylabel("Survival Rate (%)")
plt.xlabel("Time (Days)")
plt.grid()
plt.xticks(np.arange(0,10,2),("0", "10", "20", "30", "40"))
plt.show()
#not happy with legend knocking out part of graph but unsure how to fix, save for later

# %%
#Your bar graph should indicate tumor growth as red and tumor reduction as green.
#It should also include a label with the percentage change for each bar. You may want to consult this tutorial for relevant code snippets.
#green and red are not good colors as it may screw individuals with deuteranopia so i will change them

# %%
drug_base=[list(drug_vol_stuff["Capomulin"]), list(drug_vol_stuff["Ceftamin"]), list(drug_vol_stuff["Infubinol"]), 
list(drug_vol_stuff["Ketapril"]), list(drug_vol_stuff["Naftisol"]), list(drug_vol_stuff["Placebo"]), 
list(drug_vol_stuff["Propriva"]), list(drug_vol_stuff["Ramicane"]), list(drug_vol_stuff["Stelasyn"]), 
list(drug_vol_stuff["Zoniferol"])]

# %%
drug_name=["Capomulin", "Ceftamin", "Infubinol","Ketapril","Naftisol","Placebo",
          "Propriva","Ramicane", "Stelasyn", "Zoniferol"]

# %%
perc_change =[]

# %%
for x in range(len(drug_base)):
    percent = (drug_base[x][-1]-drug_base[x][0])/drug_base[x][0]*100
    perc_change.append(percent)

# %%
#please work
drug_change_df = {'Drug' : drug_name, 'Percentage Change' : perc_change }
pd.DataFrame(drug_change_df)
# Out:
#         Drug  Percentage Change
# 0  Capomulin         -19.475303
# 1   Ceftamin          42.516492
# 2  Infubinol          46.123472
# 3   Ketapril          57.028795
# 4   Naftisol          53.923347
# 5    Placebo          51.297960
# 6   Propriva          47.241175
# 7   Ramicane         -22.320900
# 8   Stelasyn          52.085134
# 9  Zoniferol          46.579751

# %%
labels2 = ["Capomulin", "Ceftamin", "Infubinol", "Ketapril", "Naftisol", "Placebo","Propriva", "Ramicane", "Stelasyn", "Zoniferol"]

# %%
# assign color to good/bad drugs drugs
good_bad_df = pd.DataFrame({"Drug":drug_name, "Percent Change":perc_change})
good_bad_df
# Out:
#         Drug  Percent Change
# 0  Capomulin      -19.475303
# 1   Ceftamin       42.516492
# 2  Infubinol       46.123472
# 3   Ketapril       57.028795
# 4   Naftisol       53.923347
# 5    Placebo       51.297960
# 6   Propriva       47.241175
# 7   Ramicane      -22.320900
# 8   Stelasyn       52.085134
# 9  Zoniferol       46.579751

# %%
colors2.pop(0)
# Out:
# 'purple'

# %%
colors2.pop(1)
# Out:
# 'orange'

# %%
for x in range(0, len(good_bad_df)):
    if perc_change[x] > 0:
        colors2.append("orange")
    else:
        colors2.append("purple")

# %%
print(colors2)
# Out:
# ['orange', 'orange', 'orange', 'orange', 'orange', 'purple', 'orange', 'orange', 'purple', 'orange', 'orange', 'orange', 'orange', 'orange', 'orange', 'purple', 'orange', 'orange']

# %%
#why in the hell do I have the first 2 items in colors2. I need to drop them
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-248-c818446826a0> in <module>
#       1 #why in the hell do I have the first 2 items in colors2. I need to drop them
# ----> 2 colors2.drop(colors2.index[[0,1]])
#
# AttributeError: 'list' object has no attribute 'drop'

# %%
print(colors2)
# Out:
# ['purple', 'orange', 'orange', 'orange', 'orange', 'orange', 'orange', 'purple', 'orange', 'orange']

# %%
colors2.pop(0)
# Out:
# 'orange'

# %%
good_bad_df
# Out:
#         Drug  Percent Change
# 0  Capomulin      -19.475303
# 1   Ceftamin       42.516492
# 2  Infubinol       46.123472
# 3   Ketapril       57.028795
# 4   Naftisol       53.923347
# 5    Placebo       51.297960
# 6   Propriva       47.241175
# 7   Ramicane      -22.320900
# 8   Stelasyn       52.085134
# 9  Zoniferol       46.579751

# %%
y_axis = [good_bad_df["Percent Change"][0],good_bad_df["Percent Change"][1],good_bad_df["Percent Change"][2],good_bad_df["Percent Change"][3],good_bad_df["Percent Change"][4],
          good_bad_df["Percent Change"][5],good_bad_df["Percent Change"][6],good_bad_df["Percent Change"][7],good_bad_df["Percent Change"][8],
          good_bad_df["Percent Change"][9]]

# %%
y_axis
# Out:
# [-19.475302666666654,
#  42.51649185811964,
#  46.123471728395046,
#  57.02879468484847,
#  53.92334713675218,
#  51.297960484848495,
#  47.24117486349207,
#  -22.320900462222223,
#  52.085134290909075,
#  46.57975086507937]

# %%
x_axis = np.arange(0,len(y_axis), 1)

# %%
good_bad_df["colors"] = colors2

# %%
color_axis = [good_bad_df["colors"][0],good_bad_df["colors"][1],good_bad_df["colors"][2],good_bad_df["colors"][3],good_bad_df["colors"][4],
              good_bad_df["colors"][5],good_bad_df["colors"][6],good_bad_df["colors"][7],good_bad_df["colors"][8],good_bad_df["colors"][9]]
labels = [good_bad_df["Percent Change"][0],good_bad_df["Percent Change"][1],good_bad_df["Percent Change"][2],good_bad_df["Percent Change"][3],
          good_bad_df["Percent Change"][4],good_bad_df["Percent Change"][5],good_bad_df["Percent Change"][6],
          good_bad_df["Percent Change"][7],good_bad_df["Percent Change"][8],good_bad_df["Percent Change"][9]]

# %%
plt.bar(x_axis, y_axis, color =color_axis, width = 1, edgecolor="black"  )
plt.title("Tumor Change Over 45 Day Treatment")
plt.ylabel("% Tumor Volume Change")
plt.grid()
plt.yticks(np.arange(-20,100,20),("-20", "0", "20", "40", "60"))
plt.xticks(np.arange(0,10,1),labels2,rotation=45)
plt.show()

# %%
good_bad_df["Colors"] = colors
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-212-f67dd3151bdd> in <module>
# ----> 1 good_bad_df["Colors"] = colors
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# ...

# %%
# The maximum x value for our chart will be 45
x_limit = 45

# List of values from 0 to 100 each value being 1 greater than the last
x_axis = np.arange(0, x_limit, 5)

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint

# Convert to DataFrame

# Preview DataFrame

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint

# Split up our data into groups 
all_groups = merge_mouse.groupby(['Timepoint','Drug'])
all_groups.head()
# Out:
#      Mouse ID      Drug  Timepoint  Tumor_Volume  Metastatic Sites
# 0        f234  Stelasyn          0     45.000000                 0
# 1        f234  Stelasyn          5     47.313491                 0
# 2        f234  Stelasyn         10     47.904324                 0
# 3        f234  Stelasyn         15     48.735197                 1
# 4        f234  Stelasyn         20     51.112713                 2
# 5        f234  Stelasyn         25     52.178602                 2
# 6        f234  Stelasyn         30     56.873817                 2
# 7        f234  Stelasyn         35     57.748758                 2
# 8        x402  Stelasyn          0     45.000000                 0
# 9        x402  Stelasyn          5     46.327570                 1
# 10       x402  Stelasyn         10     46.886962                 1
# 11       x402  Stelasyn         15     49.119948                 1
# 12       x402  Stelasyn         20     50.414750                 2
# ...

# %%
# Filter the DataFrame down only to those columns to chart
works = all_groups[["Timepoint","Drug","Tumor_Volume"]]


works.head()
# Out:
#       Timepoint      Drug  Tumor_Volume
# 0             0  Stelasyn     45.000000
# 1             5  Stelasyn     47.313491
# 2            10  Stelasyn     47.904324
# 3            15  Stelasyn     48.735197
# 4            20  Stelasyn     51.112713
# 5            25  Stelasyn     52.178602
# 6            30  Stelasyn     56.873817
# 7            35  Stelasyn     57.748758
# 8             0  Stelasyn     45.000000
# 9             5  Stelasyn     46.327570
# 10           10  Stelasyn     46.886962
# 11           15  Stelasyn     49.119948
# 12           20  Stelasyn     50.414750
# 13           25  Stelasyn     52.431737
# 14           30  Stelasyn     54.351585
# 15           35  Stelasyn     55.240962
# 16           40  Stelasyn     56.691723
# 17           45  Stelasyn     61.619606
# 18            0  Stelasyn     45.000000
# 19            5  Stelasyn     46.409143
# 20           10  Stelasyn     48.432197
# 21           15  Stelasyn     51.985263
# ...

# %%
# Create a new variable that holds the mean of our groups
Mean_Tumor = all_groups['Tumor_Volume'].mean()
Mean_Tumor.head()
# Out:
# Timepoint  Drug
# 0          Capomulin    45.0
#            Ceftamin     45.0
#            Infubinol    45.0
#            Ketapril     45.0
#            Naftisol     45.0
# Name: Tumor_Volume, dtype: float64

# %%
# Creating a dataframe object 
Tumor_volume_df = pd.DataFrame(Mean_Tumor) 

# Creating a dataframe object from listoftuples
Tumor_volume_df
# Out:
#                      Tumor_Volume
# Timepoint Drug
# 0         Capomulin     45.000000
#           Ceftamin      45.000000
#           Infubinol     45.000000
#           Ketapril      45.000000
#           Naftisol      45.000000
#           Placebo       45.000000
#           Propriva      45.000000
#           Ramicane      45.000000
#           Stelasyn      45.000000
#           Zoniferol     45.000000
# 5         Capomulin     44.266086
#           Ceftamin      46.503051
#           Infubinol     47.062001
#           Ketapril      47.389175
#           Naftisol      46.796098
#           Placebo       47.125589
#           Propriva      47.248967
#           Ramicane      43.944859
#           Stelasyn      47.527452
#           Zoniferol     46.851818
# 10        Capomulin     43.084291
#           Ceftamin      48.285125
#           Infubinol     49.403909
#           Ketapril      49.582269
#           Naftisol      48.694210
#           Placebo       49.423329
# ...

# %%
#scatter

# %%
# Create a new variable that holds the se of our groups
SE_Tumor = all_groups['Tumor_Volume'].sem()
SE_Tumor.head()
# Out:
# Timepoint  Drug
# 0          Capomulin    0.0
#            Ceftamin     0.0
#            Infubinol    0.0
#            Ketapril     0.0
#            Naftisol     0.0
# Name: Tumor_Volume, dtype: float64

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked
#want index to be timepoint (rows) and columns to be drug and data is average t

# %%
# Convert to DataFrame

# Preview DataFrame

# %%
print(f"The SEM value for the tumors data is {sem(merge_mouse.Tumor_Volume)}")
# Out:
# The SEM value for the tumors data is 0.20316139580370923

# %%
TimePoint=all_groups['Timepoint']
TimePoint.head()
# Out:
# 0        0
# 1        5
# 2       10
# 3       15
# 4       20
# 5       25
# 6       30
# 7       35
# 8        0
# 9        5
# 10      10
# 11      15
# 12      20
# 13      25
# 14      30
# 15      35
# 16      40
# 17      45
# 18       0
# 19       5
# 20      10
# 21      15
# 22      20
# 23      25
# 24      30
# 25      35
# 26      40
# 27      45
# 28       0
# 29       5
#         ..
# 1745     0
# 1746     5
# 1747    10
# 1748     0
# 1749     5
# 1750    10
# 1751    15
# 1752    20
# 1753    25
# 1754    30
# 1755     0
# 1756     5
# 1757    10
# 1758    15
# 1759    20
# 1760    25
# 1761    30
# 1762    35
# 1763    40
# 1764    45
# 1768    15
# 1769    20
# 1770    25
# 1771    30
# 1772    35
# 1780    35
# 1781    40
# 1782    45
# 1802    40
# 1803    45
# Name: Timepoint, Length: 500, dtype: int64

# %%
Drug=all_groups['Drug']
Drug.head()
# Out:
# 0       Stelasyn
# 1       Stelasyn
# 2       Stelasyn
# 3       Stelasyn
# 4       Stelasyn
# 5       Stelasyn
# 6       Stelasyn
# 7       Stelasyn
# 8       Stelasyn
# 9       Stelasyn
# 10      Stelasyn
# 11      Stelasyn
# 12      Stelasyn
# 13      Stelasyn
# 14      Stelasyn
# 15      Stelasyn
# 16      Stelasyn
# 17      Stelasyn
# 18      Stelasyn
# 19      Stelasyn
# 20      Stelasyn
# 21      Stelasyn
# 22      Stelasyn
# 23      Stelasyn
# 24      Stelasyn
# 25      Stelasyn
# 26      Stelasyn
# 27      Stelasyn
# 28      Stelasyn
# 29      Stelasyn
#           ...
# 1745     Placebo
# 1746     Placebo
# 1747     Placebo
# 1748     Placebo
# 1749     Placebo
# 1750     Placebo
# 1751     Placebo
# 1752     Placebo
# 1753     Placebo
# 1754     Placebo
# 1755     Placebo
# 1756     Placebo
# 1757     Placebo
# 1758     Placebo
# 1759     Placebo
# 1760     Placebo
# 1761     Placebo
# 1762     Placebo
# 1763     Placebo
# 1764     Placebo
# 1768     Placebo
# ...

# %%
#round it after I get the other crap in place

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame

# %%
Tumor_average = pd_dataframe(all_groups['Tumor_Volume'].mean())
Tumor_average
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-55e090c79849> in <module>
# ----> 1 Tumor_average = pd_dataframe(all_groups['Tumor_Volume'].mean())
#       2 Tumor_average
#
# NameError: name 'pd_dataframe' is not defined

# %%
# The maximum x value for our chart will be 45
x_limit = 45

# %%
# Creating a summary DataFrame using above values, irritating output bd by m f
pa_df = pd.DataFrame({"Timepoint": [TimePoint],
                            "Drug": [Drug],
                            "Tumor Volume (mm3)": [Tumor_average],
                             "Tumor SE": [mouse_se]})
pa_df.head()
# Out:
#                                            Timepoint  \
# 0  <pandas.core.groupby.generic.SeriesGroupBy obj...
#
#                                                 Drug  \
# 0  <pandas.core.groupby.generic.SeriesGroupBy obj...
#
#                                   Tumor Volume (mm3)  \
# 0  Timepoint  Drug
# 0          Capomulin    4...
#
#                                             Tumor SE
# 0  Timepoint  Drug
# 0          Capomulin    0...
